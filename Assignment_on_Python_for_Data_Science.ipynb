# %% [markdown]
# ## **Assignment on Python for Data Science**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##1. Read the dataset to python environment.

# %%
#1: Read the dataset

df = pd.read_excel('/content/drive/MyDrive/iris_aswin.xls')
print(df.head())
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %% [markdown]
# ## 2. Display the columns in the dataset.

# %%
# Step 2: Display columns
print("Columns in the dataset:")
print(df.columns)
# Out:
# Columns in the dataset:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# ##3. Calculate the mean of each column of the dataset.

# %%
# Calculate mean of each column
column_means = df.mean()
print("\nMean of each column:")
print(column_means)
# Out:
# Mean of each column:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64
# <ipython-input-12-5225172ee2f4>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   column_means = df.mean()

# %% [markdown]
# ##4. Check for the null values present in the dataset.

# %%
# Check for null values
print("\nNull values in the dataset:")
print(df.isnull().sum())
# Out:
# Null values in the dataset:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# ##5. Perform meaningful visualizations using the dataset. Bring at least 3 visualizations.

# %%
# Visualization 1: Pairplot
sns.pairplot(df, hue='Classification')
plt.title("Pairplot of Iris Dataset")
plt.show()

# %%
# Visualization 2: Box plot
plt.figure(figsize=(10, 6))
sns.boxplot(data=df.iloc[:, :-1])
plt.title("Box Plot of Iris Dataset")
plt.show()

# %%
# Visualization 3: Correlation heatmap
plt.figure(figsize=(8, 6))
correlation_matrix = df.iloc[:, :-1].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap of Iris Dataset")
plt.show()
